# %%
#import pandas

import pandas as pd

# %%
#load the budget data

budgetdf = pd.read_csv('budget_data.csv')
budgetdf.head()
# Out:
#        Date  Profit/Losses
# 0  Jan-2010         867884
# 1  Feb-2010         984655
# 2  Mar-2010         322013
# 3  Apr-2010         -69417
# 4  May-2010         310503

# %%
#check data type

budgetdf.dtypes
# Out:
# Date             object
# Profit/Losses     int64
# dtype: object

# %%
budgetdf = pd.read_csv('budget_data.csv', parse_dates=['Date'])
budgetdf['Date'] = budgetdf['Date'].dt.to_period(freq = 'M')
budgetdf.head()
# Out:
#       Date  Profit/Losses
# 0  2010-01         867884
# 1  2010-02         984655
# 2  2010-03         322013
# 3  2010-04         -69417
# 4  2010-05         310503

# %%
#check data type

budgetdf.dtypes
# Out:
# Date             period[M]
# Profit/Losses        int64
# dtype: object

# %%
#aggregate budget data

budgetdf = budgetdf.groupby(by=['Date']).sum()
budgetdf
# Out:
#          Profit/Losses
# Date
# 2010-01         867884
# 2010-02         984655
# 2010-03         322013
# 2010-04         -69417
# 2010-05         310503
# ...                ...
# 2016-10         102685
# 2016-11         795914
# 2016-12          60988
# 2017-01         138230
# 2017-02         671099
#
# [86 rows x 1 columns]

# %%
#summary stats

budgetdf.describe()
# Out:
#        Profit/Losses
# count   8.600000e+01
# mean    4.463090e+05
# std     5.363579e+05
# min    -1.196225e+06
# 25%     1.821620e+05
# 50%     5.703280e+05
# 75%     7.952262e+05
# max     1.170593e+06

# %%
#finding how many months we have
budgetdf.shape[0]
# Out:
# 86

# %%
#creating net change

# 1. take prior date value
# 2. present date value
# 3. minus 2 - 1

budgetdf['shift1'] = budgetdf['Profit/Losses'].shift(1)
budgetdf.head()
# Out:
#          Profit/Losses    shift1
# Date
# 2010-01         867884       NaN
# 2010-02         984655  867884.0
# 2010-03         322013  984655.0
# 2010-04         -69417  322013.0
# 2010-05         310503  -69417.0

# %%
#calculate monthly change

budgetdf['Monthy_change'] = budgetdf['Profit/Losses'] - budgetdf['shift1']
budgetdf.head(30)
# Out:
#          Profit/Losses     shift1  Monthy_change
# Date
# 2010-01         867884        NaN            NaN
# 2010-02         984655   867884.0       116771.0
# 2010-03         322013   984655.0      -662642.0
# 2010-04         -69417   322013.0      -391430.0
# 2010-05         310503   -69417.0       379920.0
# 2010-06         522857   310503.0       212354.0
# 2010-07        1033096   522857.0       510239.0
# 2010-08         604885  1033096.0      -428211.0
# 2010-09        -216386   604885.0      -821271.0
# 2010-10         477532  -216386.0       693918.0
# 2010-11         893810   477532.0       416278.0
# 2010-12         -80353   893810.0      -974163.0
# 2011-01         779806   -80353.0       860159.0
# 2011-02        -335203   779806.0     -1115009.0
# 2011-03         697845  -335203.0      1033048.0
# 2011-04         793163   697845.0        95318.0
# 2011-05         485070   793163.0      -308093.0
# 2011-06         584122   485070.0        99052.0
# ...

# %%
#get the max of monthly change

budgetdf['Monthy_change'].max()
# Out:
# 1926159.0

# %%
#getting the date/index of the greatest increase

budgetdf.Monthy_change[budgetdf.Monthy_change == budgetdf['Monthy_change'].max()].index.tolist()
max_date=budgetdf.Monthy_change[budgetdf.Monthy_change == budgetdf['Monthy_change'].max()].index.tolist()

# %%
max_date[0].strftime('%b-%Y')
# Out:
# 'Feb-2012'

# %%
#getting the date/index of the greatest decrease

budgetdf.Monthy_change[budgetdf.Monthy_change == budgetdf['Monthy_change'].min()].index.tolist()
min_date=budgetdf.Monthy_change[budgetdf.Monthy_change == budgetdf['Monthy_change'].min()].index.tolist()

# %%
min_date[0].strftime('%b-%Y')
# Out:
# 'Sep-2013'

# %%
#create a summary into a txt file


with open('Budget_Summary.txt',"w") as file:
    
    
    summary = f"""
    Financial Analysis
    -------------------------
    Total Months: {budgetdf.shape[0]}
    
    Total: ${round(budgetdf['Profit/Losses'].sum(),2)}
    
    Average Change: ${round(budgetdf['Monthy_change'].mean(),2)}
    
    Greatest Increase in Profits: {max_date[0].strftime('%b-%Y')} (${(budgetdf['Monthy_change'].max()):.0f})
  
    Greatest Decrease in Profits: {min_date[0].strftime('%b-%Y')} (${(budgetdf['Monthy_change'].min()):.0f})
    """
    
    file.write(summary)
